# %%
print("Hello World! ")
# Out:
# Hello World!

# %%
# import pyautogui
import time
import pyperclip
import pyautogui

pyautogui.PAUSE = 1
# abrir navegador
# pyautogui.press("winleft")
# pyautogui.write("chrome")
# pyautogui.press("enter")
pyautogui.alert("vai começar, aperte OK e não mexa em nada")
pyautogui.hotkey('ctrl', 't')
# abrir drive
# ensinar aqui o write
link = "https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga"
pyperclip.copy(link)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
time.sleep(5)

pyautogui.click(x=388, y=279, clicks=2)
pyautogui.click(x=389, y=363)
pyautogui.click(x=1719, y=152)
pyautogui.click(x=1540, y=542)
time.sleep(2)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
pyautogui.hotkey('ctrl', 't')
pyperclip.copy("mail.google.com/mail/u/0/#inbox")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
time.sleep(5)

pyautogui.click(x=62, y=172)
time.sleep(2)

pyautogui.click(x=1332, y=491)
pyautogui.write('pitigui@gmail.com')
pyautogui.press("tab")

pyautogui.write("Relatório de Vendas")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("tab")
texto = """
Prezados, boa noite


Segue o faruramento de ontem que foi de: R${faturamento:}
A quantidade doi de: {quantidade:,}

Att.

Camila
"""

pyperclip.copy(texto)
pyautogui.hotkey('ctrl', 'v')

pyautogui.hotkey('ctrl', 'enter')

# %%
time.sleep(6)
pyautogui.position()
# Out:
# Point(x=694, y=430)

# %%
import pandas

tabela = pandas.read_excel(r"C:\Users\ADM\Downloads\Jupyter\Vendas - Dez (1).xlsx")
display(tabela)

quantidade = tabela["Quantidade"].sum()
faturamento = tabela["Valor Final"].sum()

print(quantidade)
print(faturamento)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...
